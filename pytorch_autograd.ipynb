# %% [markdown]
# - Need of Autograd?
#     - suppose we have mathematical eqaution $$y = x^2$$
#     - let's say we have challenge to write python program by which we can find derivative of $y$ for given $x$.
#     - basically program should return: $$dy/dx$$ for any value of: $$x$$
#     - so : $$dy/dx = 2x$$
#     - $$y = x^2$$  $$z = sin(y)$$ $$ x = dz/dx$$ $$dz/dx = (dz/dy)* (dy/dx)$$ $$dx/dy = cosy$$ $$dy/dx = 2xcos(y)$$ $$2xcos(x^2)$$
#
#     - $$y = x^2$$ $$z = siny$$ $$u = e^2$$ $$du/dx = du/dz* dz/dy* dy/dx$$
#
#     - This is not efficient so autograd comes in picture.
#     - Autograd is core component of pytorch that provide automatic differenciation of tensor operations. It enables gradient computation, which is essential for training machine learning model using optimization algorithms like gradient descent.

# %%
def dy_dx(x):
    return 2 * x

# %%
dy_dx(3)
# Out:
# 6

# %%
import math

def dz_dx(x):
    return 2 * x * math.cos(x ** 2)

# %%
dz_dx(3)
# Out:
# -5.466781571308061

# %%
import torch

# %%
x = torch.tensor(3.0,requires_grad=True,device="cuda")

# %%
y = x ** 2

# %%
x
# Out:
# tensor(3., device='cuda:0', requires_grad=True)

# %%
y
# Out:
# tensor(9., device='cuda:0', grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6., device='cuda:0')

# %%
x = torch.tensor(3.0,requires_grad=True, device= "cuda")

# %%
y =  x ** 2

# %%
z = torch.sin(y)

# %%
x
# Out:
# tensor(3., device='cuda:0', requires_grad=True)

# %%
y
# Out:
# tensor(9., device='cuda:0', grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, device='cuda:0', grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668, device='cuda:0')

# %% [markdown]
# - $dl/dw$
# - $dl/db$
# - $dl/dw = dl/dypred * dypred/dz * dz/dw$
# - $dl/db = dl/dypred * dypred/dz$
# - $dl/dypred = (ypred - y) / ypred(1- ypred)$
# - $dypred/dz = ypred(1-ypred)$
# - $dz/dw = x$
# - $dz/db = 1$
# - $dl/dw = (ypred-y) x$
# - $dl/db = (ypred -y) * 1$

# %%
import torch
x = torch.tensor(6.7) #inp feature
y = torch.tensor(0.0) # true label (binary)

w = torch.tensor(1.0) # weight
b = torch.tensor(0.0) # bias

# %%
# binary cross entropy (loss)
def binary_cross_entropy_loss(prediction,target):
    epsilon = 1e-8 # to prevent log(0)
    prediction = torch.clamp(prediction,epsilon,1-epsilon)
    return -(target * torch.log(prediction) + (1-target)* torch.log(1-prediction))

# %%
# forward pass
z = w * x + b # weighted sum(linear part)
y_pred = torch.sigmoid(z) # prediction probability

# compute binary cross entropy loss
loss = binary_cross_entropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# derivation
# 1. dl/d(y_pred) : loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred -y) / (y_pred * (1-y_pred))

# 2. dy_pred/dz : Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db : z with respect to w and b
dz_dw = x # dz/dw =x
dz_db = 1 # dz/db = 1 (bias contribute directly to z)

dl_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dl_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight(dw): {dl_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dl_db}")
# Out:
# Manual Gradient of loss w.r.t weight(dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %%
x = torch.tensor(6.7, device="cuda")
y = torch.tensor(0.0,device="cuda")

# %%
xw = torch.tensor(1.0,device="cuda",requires_grad=True)
b = torch.tensor(0.0,device="cuda",requires_grad=True)

# %%
w
# Out:
# tensor(1., device='cuda:0', requires_grad=True)

# %%
b
# Out:
# tensor(0., device='cuda:0', requires_grad=True)

# %%
z = w * x +b
z
# Out:
# tensor(6.7000, device='cuda:0', grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, device='cuda:0', grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred,y)
loss
# Out:
# tensor(6.7012, device='cuda:0', grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad, b.grad)
# Out:
# tensor(6.6918, device='cuda:0') tensor(0.9988, device='cuda:0')

# %%
x = torch.tensor([1.0,2.0,3.0],requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearing gradinents
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# how to disable gradient tracking (it require when nueral network is trained)
x = torch.tensor(2.0,requires_grad=True)
z
# Out:
# tensor(6.7000, device='cuda:0', grad_fn=<AddBackward0>)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
# option 1 - requires_grad_(False)
# option 2 - detach()
# option 3 - torch.no_grad()

# %%
# option 1 - requires_grad_(False)
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y = x ** 2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_11557/1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     628                 inputs=inputs,
#     629             )
# --> 630         torch.autograd.backward(
#     631             self, gradient, retain_graph, create_graph, inputs=inputs
#     632         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     362     # some Python versions print out the first line of a multi-line function
#     363     # calls in the traceback and some print out the last line
# --> 364     _engine_run_backward(
#     365         tensors,
#     366         grad_tensors_,
#
# ...

# %%
# option 2 - detach()
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z = x.detach()
z
# Out:
# tensor(2.)

# %%
y = x ** 2

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1 = z **2
y1
# Out:
# tensor(4.)

# %%
y.backward()

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_11557/3844781142.py in <cell line: 0>()
# ----> 1 y1.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     628                 inputs=inputs,
#     629             )
# --> 630         torch.autograd.backward(
#     631             self, gradient, retain_graph, create_graph, inputs=inputs
#     632         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     362     # some Python versions print out the first line of a multi-line function
#     363     # calls in the traceback and some print out the last line
# --> 364     _engine_run_backward(
#     365         tensors,
#     366         grad_tensors_,
#
# ...

# %%
# option 3 - torch.no_grad()
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
with  torch.no_grad():
    y = x ** 2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_11557/1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     628                 inputs=inputs,
#     629             )
# --> 630         torch.autograd.backward(
#     631             self, gradient, retain_graph, create_graph, inputs=inputs
#     632         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     362     # some Python versions print out the first line of a multi-line function
#     363     # calls in the traceback and some print out the last line
# --> 364     _engine_run_backward(
#     365         tensors,
#     366         grad_tensors_,
#
# ...
